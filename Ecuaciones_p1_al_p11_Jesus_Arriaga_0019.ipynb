# %% [markdown]
# <a href="https://colab.research.google.com/github/JesusArriaga128/Mate-ecuaciones-lineales-Jesus-0019/blob/main/Ecuaciones_p1_al_p11_Jesus_Arriaga_0019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Jesus Arriaga NL = 5 Fecha 15/04/2026
# ## Ecuaciones lineales
# #### Ecuacion 1
# $x + 8 = 15$
# ## Paso 1: Identificamos que el $+8$ debe moverse al lado derecho para dejar sola a la $x$.
# ## Al cruzar el signo $=$, cambia a resta.
# ## Paso 2: Escribimos la nueva igualdad: $x = 15 - 8$.
# ## Paso 3: Resolvemos la operación final: $x = 7$.
#
# *   Elemento de la lista
# *   Elemento de la lista

# %%
# Resolución 1
valor_derecha = 15
numero_a_mover = 8
x = valor_derecha - numero_a_mover
print(f"Resultado 1: {x}")
# Out:
# Resultado 1: 7

# %% [markdown]
# #### Ecuacion 3
# $3x + 4x = 21$
# ### Paso 1: Agrupamos los términos semejantes en el lado izquierdo ($3x$ y $4x$).
# ### Sumamos sus coeficientes: $3 + 4 = 7$.
# ### Paso 2: La ecuación simplificada es $7x = 21$.
# ## Paso 3: El $7$ que multiplica a la $x$ pasa dividiendo al $21$.
# ## Paso 4: Resolvemos: $x = 3$.

# %%
# Resolución 3
coeficiente_1 = 3
coeficiente_2 = 4
total_derecha = 21
x = total_derecha / (coeficiente_1 + coeficiente_2)
print(f"Resultado 2: {int(x)}")
# Out:
# Resultado 2: 3

# %% [markdown]
# #### Ecuacion 5
# $6a - 2a + a = 20$
# ### Paso 1: Agrupamos los términos con la letra $a$.
# #### Recuerda que $a$ es lo mismo que $1a$.
# ### Paso 2: Operamos: $6a - 2a = 4a$, y luego $4a + 1a = 5a$.
# ### Paso 3: La ecuación queda como $5a = 20$.
# ### Paso 4: El $5$ pasa dividiendo: $a = 20 / 5$. Resultado: $a = 4$.

# %%
# Resolución 5
coeficientes_a = 6 - 2 + 1
total = 20
a = total / coeficientes_a
print(f"Resultado 3: {int(a)}")
# Out:
# Resultado 3: 4

# %% [markdown]
# #### Ecuacion 7
# $4x + 3 = 2x + 11$
# ## Paso 1: Agrupamos las $x$ en la izquierda.
# ## El $2x$ pasa como $-2x$.Paso 2:
# ## Agrupamos los números en la derecha.
# ## El $+3$ pasa como $-3$.
# ### Paso 3: La ecuación se ve así: $4x - 2x = 11 - 3$.
# ## Paso 4: Resolvemos las restas en ambos lados: $2x = 8$.
# ## Paso 5: El $2$ pasa dividiendo: $x = 8 / 2$. Resultado: $x = 4$

# %%
# Resolución 7
x_izq = 4
x_der = 2
num_der = 11
num_izq = 3
x = (num_der - num_izq) / (x_izq - x_der)
print(f"Resultado 4: {int(x)}")
# Out:
# Resultado 4: 4

# %% [markdown]
# #### Ecuacion 9
# $9m + 4 = 5m + 20$
# ## Paso 1: Movemos términos semejantes:
# ##  El $5m$ a la izquierda y el $4$ a la derecha.
# ## Paso 2: Escribimos la agrupación: $9m - 5m = 20 - 4$.
# ## Paso 3: Simplificamos ambos lados: $4m = 16$.
# ### Paso 4: Despejamos la $m$ dividiendo: $m = 16 / 4$. Resultado: $m = 4$

# %%
# Resolución 9
m_izq = 9
m_der = 5
num_der = 20
num_izq = 4
m = (num_der - num_izq) / (m_izq - m_der)
print(f"Resultado 5: {int(m)}")
# Out:
# Resultado 5: 4

# %% [markdown]
# #### Ecuacion 11
# $6a + 5 = 2a + 21$
# ## Paso 1: Llevamos las letras $a$ a un lado: $6a - 2a$.
# ### Paso 2: Llevamos los números al otro: $21 - 5$.
# ## Paso 3: La ecuación queda: $4a = 16$.
# ### Paso 4: Resolvemos la división: $a = 16 / 4$.
# ## Resultado: $a = 4$.

# %%
# Resolución 11
a_izq = 6
a_der = 2
num_der = 21
num_izq = 5
a = (num_der - num_izq) / (a_izq - a_der)
print(f"Resultado 6: {int(a)}")
# Out:
# Resultado 6: 4
